# %% [markdown]
# ### PYTHON基礎課程
# * python基本資料型別
# * 第一次執行需要安裝核心
# * 關閉自動完成(右下角Copiler)

# %%
print("Hello!Python")
print("以下是python的基本資料類型(int,float,str,bool)")
15 #整數,(int)
15.0 #浮點數,(float)
"15.0" #字串, (str)
'15.0' #字串,(str)
True #布林值, (bool)
False #布林值, (bool)
# Out:
# Hello!Python
# 以下是python的基本資料類型(int,float,str,bool)
# False
